# %%
from sklearn.decomposition import *
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from sklearn.manifold import *
from umap import UMAP
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('ridge_regression_default_alpha ( removed missing values ).csv', index_col = 0)

# %%
df.head()
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff  \
# Country
# ABW          2.110374e-06    -5.234120e-05      0.000281     -0.000118
# AGO          2.288403e-03    -2.036148e-04      0.021916      0.022261
# ALB         -3.211943e-06    -6.821917e-05      0.003194      0.000979
# ARM         -3.036229e-06    -3.880737e-05      0.002687      0.000907
# ATG          7.793166e-08    -1.460810e-08      0.000292     -0.000074
#
#          Test_Score  Export_GDP_Correlation
# Country
# ABW       -0.478724                0.289910
# AGO        0.955084                0.967478
# ALB        0.979368                0.945574
# ARM        0.943776                0.897635
# ATG        0.371350               -0.088238

# %%
df.drop(columns = ['Test_Score', 'Export_GDP_Correlation'], inplace = True)

# %%
df
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff
# Country
# ABW          2.110374e-06    -5.234120e-05      0.000281     -0.000118
# AGO          2.288403e-03    -2.036148e-04      0.021916      0.022261
# ALB         -3.211943e-06    -6.821917e-05      0.003194      0.000979
# ARM         -3.036229e-06    -3.880737e-05      0.002687      0.000907
# ATG          7.793166e-08    -1.460810e-08      0.000292     -0.000074
# ...                   ...              ...           ...           ...
# VUT          3.968272e-07    -6.236072e-06      0.000258      0.000090
# WSM          6.811790e-08    -4.009710e-06      0.000293     -0.000026
# YEM         -1.726670e-05     1.300573e-03      0.007831     -0.000954
# ZAF          1.645505e-02    -3.792556e-03      0.091649      0.044253
# ZMB          3.187132e-04    -1.095131e-03      0.006054      0.003701
#
# [163 rows x 4 columns]

# %%
df_ = df.copy()
df_
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff
# Country
# ABW          2.110374e-06    -5.234120e-05      0.000281     -0.000118
# AGO          2.288403e-03    -2.036148e-04      0.021916      0.022261
# ALB         -3.211943e-06    -6.821917e-05      0.003194      0.000979
# ARM         -3.036229e-06    -3.880737e-05      0.002687      0.000907
# ATG          7.793166e-08    -1.460810e-08      0.000292     -0.000074
# ...                   ...              ...           ...           ...
# VUT          3.968272e-07    -6.236072e-06      0.000258      0.000090
# WSM          6.811790e-08    -4.009710e-06      0.000293     -0.000026
# YEM         -1.726670e-05     1.300573e-03      0.007831     -0.000954
# ZAF          1.645505e-02    -3.792556e-03      0.091649      0.044253
# ZMB          3.187132e-04    -1.095131e-03      0.006054      0.003701
#
# [163 rows x 4 columns]

# %%
df_coeff = df.copy()
df_coeff
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff
# Country
# ABW          2.110374e-06    -5.234120e-05      0.000281     -0.000118
# AGO          2.288403e-03    -2.036148e-04      0.021916      0.022261
# ALB         -3.211943e-06    -6.821917e-05      0.003194      0.000979
# ARM         -3.036229e-06    -3.880737e-05      0.002687      0.000907
# ATG          7.793166e-08    -1.460810e-08      0.000292     -0.000074
# ...                   ...              ...           ...           ...
# VUT          3.968272e-07    -6.236072e-06      0.000258      0.000090
# WSM          6.811790e-08    -4.009710e-06      0.000293     -0.000026
# YEM         -1.726670e-05     1.300573e-03      0.007831     -0.000954
# ZAF          1.645505e-02    -3.792556e-03      0.091649      0.044253
# ZMB          3.187132e-04    -1.095131e-03      0.006054      0.003701
#
# [163 rows x 4 columns]

# %% [markdown]
# # Standard Scaler for each row

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_coeff.T).T

# %%
df_scaled = pd.DataFrame(df_scaled, index = df_coeff.index, columns = df_coeff.columns)
df_scaled
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff
# Country
# ABW             -0.170906        -0.528774      1.662550     -0.962870
# AGO             -0.878458        -1.114435      0.980119      1.012775
# ALB             -0.779767        -0.829059      1.644194     -0.035367
# ARM             -0.806033        -0.838390      1.626994      0.017428
# ATG             -0.386761        -0.387420      1.691054     -0.916874
# ...                   ...              ...           ...           ...
# VUT             -0.798952        -0.861285      1.618049      0.042188
# WSM             -0.498410        -0.529369      1.726983     -0.699204
# YEM             -0.598467        -0.215124      1.684409     -0.870818
# ZAF             -0.577900        -1.143553      1.522775      0.198678
# ZMB             -0.686332        -1.190172      1.357659      0.518845
#
# [163 rows x 4 columns]

# %%
df = df_scaled
df
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff
# Country
# ABW             -0.170906        -0.528774      1.662550     -0.962870
# AGO             -0.878458        -1.114435      0.980119      1.012775
# ALB             -0.779767        -0.829059      1.644194     -0.035367
# ARM             -0.806033        -0.838390      1.626994      0.017428
# ATG             -0.386761        -0.387420      1.691054     -0.916874
# ...                   ...              ...           ...           ...
# VUT             -0.798952        -0.861285      1.618049      0.042188
# WSM             -0.498410        -0.529369      1.726983     -0.699204
# YEM             -0.598467        -0.215124      1.684409     -0.870818
# ZAF             -0.577900        -1.143553      1.522775      0.198678
# ZMB             -0.686332        -1.190172      1.357659      0.518845
#
# [163 rows x 4 columns]

# %% [markdown]
# # KMeans clustering for Coefficients

# %%
df_coef = df.copy()

# %%
from sklearn.cluster import KMeans
inertia_values = []

cluster_range = range(1, 20)
for k in cluster_range:
    model = KMeans(n_clusters=k, n_init='auto', random_state=42)
    model.fit(df_coef)
    inertia_values.append(model.inertia_)


plt.figure(figsize=(10, 6))
plt.plot(cluster_range, inertia_values, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow method for optimal')
plt.xticks(cluster_range)
plt.show()

# %%
n_clusters = 11
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df_coef['Cluster'] = kmeans.fit_predict(df_coef)

# %%
from sklearn.metrics import silhouette_score

sil_score = silhouette_score(df_coef.drop(columns=['Cluster']), df_coef['Cluster'])
print("Silhouette Score:", ((sil_score + 1) / 2) * 100)
# Out:
# Silhouette Score: 72.85496814530325

# %%
df_coef.Cluster.value_counts()
# Out:
# Cluster
# 1     37
# 5     33
# 9     28
# 2     18
# 10    11
# 6     10
# 3     10
# 0      7
# 4      4
# 7      3
# 8      2
# Name: count, dtype: int64

# %%
df_['Cluster'] = df_coef['Cluster']

# %%
df_
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff  \
# Country
# ABW          2.110374e-06    -5.234120e-05      0.000281     -0.000118
# AGO          2.288403e-03    -2.036148e-04      0.021916      0.022261
# ALB         -3.211943e-06    -6.821917e-05      0.003194      0.000979
# ARM         -3.036229e-06    -3.880737e-05      0.002687      0.000907
# ATG          7.793166e-08    -1.460810e-08      0.000292     -0.000074
# ...                   ...              ...           ...           ...
# VUT          3.968272e-07    -6.236072e-06      0.000258      0.000090
# WSM          6.811790e-08    -4.009710e-06      0.000293     -0.000026
# YEM         -1.726670e-05     1.300573e-03      0.007831     -0.000954
# ZAF          1.645505e-02    -3.792556e-03      0.091649      0.044253
# ZMB          3.187132e-04    -1.095131e-03      0.006054      0.003701
#
#          Cluster
# Country
# ABW            2
# AGO            6
# ALB            1
# ARM            1
# ATG            2
# ...          ...
# VUT            1
# WSM            2
# YEM            2
# ZAF           10
# ZMB            3
#
# [163 rows x 5 columns]

# %% [markdown]
# # Dimensionality Reduction

# %%
def visualize_dim_red(name, alg, data, clusters):
    al = alg(n_components=2)
    tr = al.fit_transform(data)

    plt.scatter(tr[:, 0], tr[:, 1], c=clusters, cmap='viridis', alpha=0.7, edgecolors='k')

    plt.title(name)
    plt.xlabel("Component 1")
    plt.ylabel("Component 2")
    plt.colorbar(label="Cluster Label")
    plt.show()

algs = {'PCA': PCA, 'tSNE': TSNE, 'UMAP': UMAP, 'ICA': FastICA, 'Isomap': Isomap}

 
clusters = df_coef['Cluster']


df_features = df_coef.drop(columns=['Cluster'])


for name, alg in algs.items():
    visualize_dim_red(name, alg, df_features, clusters)

# %%
df
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff
# Country
# ABW             -0.170906        -0.528774      1.662550     -0.962870
# AGO             -0.878458        -1.114435      0.980119      1.012775
# ALB             -0.779767        -0.829059      1.644194     -0.035367
# ARM             -0.806033        -0.838390      1.626994      0.017428
# ATG             -0.386761        -0.387420      1.691054     -0.916874
# ...                   ...              ...           ...           ...
# VUT             -0.798952        -0.861285      1.618049      0.042188
# WSM             -0.498410        -0.529369      1.726983     -0.699204
# YEM             -0.598467        -0.215124      1.684409     -0.870818
# ZAF             -0.577900        -1.143553      1.522775      0.198678
# ZMB             -0.686332        -1.190172      1.357659      0.518845
#
# [163 rows x 4 columns]

# %%
df_coef
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff  \
# Country
# ABW             -0.170906        -0.528774      1.662550     -0.962870
# AGO             -0.878458        -1.114435      0.980119      1.012775
# ALB             -0.779767        -0.829059      1.644194     -0.035367
# ARM             -0.806033        -0.838390      1.626994      0.017428
# ATG             -0.386761        -0.387420      1.691054     -0.916874
# ...                   ...              ...           ...           ...
# VUT             -0.798952        -0.861285      1.618049      0.042188
# WSM             -0.498410        -0.529369      1.726983     -0.699204
# YEM             -0.598467        -0.215124      1.684409     -0.870818
# ZAF             -0.577900        -1.143553      1.522775      0.198678
# ZMB             -0.686332        -1.190172      1.357659      0.518845
#
#          Cluster
# Country
# ABW            2
# AGO            6
# ALB            1
# ARM            1
# ATG            2
# ...          ...
# VUT            1
# WSM            2
# YEM            2
# ZAF           10
# ZMB            3
#
# [163 rows x 5 columns]

# %%
df_['Cluster'] = df_coef['Cluster']

# %%
df_
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff  \
# Country
# ABW          2.110374e-06    -5.234120e-05      0.000281     -0.000118
# AGO          2.288403e-03    -2.036148e-04      0.021916      0.022261
# ALB         -3.211943e-06    -6.821917e-05      0.003194      0.000979
# ARM         -3.036229e-06    -3.880737e-05      0.002687      0.000907
# ATG          7.793166e-08    -1.460810e-08      0.000292     -0.000074
# ...                   ...              ...           ...           ...
# VUT          3.968272e-07    -6.236072e-06      0.000258      0.000090
# WSM          6.811790e-08    -4.009710e-06      0.000293     -0.000026
# YEM         -1.726670e-05     1.300573e-03      0.007831     -0.000954
# ZAF          1.645505e-02    -3.792556e-03      0.091649      0.044253
# ZMB          3.187132e-04    -1.095131e-03      0.006054      0.003701
#
#          Cluster
# Country
# ABW            2
# AGO            6
# ALB            1
# ARM            1
# ATG            2
# ...          ...
# VUT            1
# WSM            2
# YEM            2
# ZAF           10
# ZMB            3
#
# [163 rows x 5 columns]

# %%
df_.to_csv('clustered_data.csv')

# %% [markdown]
# # Dimentionality reduction of PCA

# %%
pca = PCA(0.95)
df_pca = pca.fit_transform(df)
df_pca
# Out:
# array([[-1.17909108e+00,  4.15042245e-01,  1.54934410e-01],
#        [ 1.06661161e+00,  4.64323816e-02, -2.79810644e-02],
#        [-1.92394667e-01, -1.60456419e-01,  2.56575173e-02],
#        [-1.32440885e-01, -1.76544560e-01,  2.82685648e-02],
#        [-1.13243909e+00,  2.27025351e-01,  3.33752367e-01],
#        [ 7.87366706e-02, -1.83023272e-01, -1.21493833e-02],
#        [-7.79857881e-02, -1.89621912e-01,  3.13806577e-02],
#        [ 1.80803236e+00,  4.78338785e-01,  3.72537282e-01],
#        [-3.35642661e-01, -1.01662891e-01,  4.03967059e-03],
#        [-8.35347783e-02, -1.84415531e-01,  2.49006990e-02],
#        [-3.59181437e-01, -6.00269280e-02, -4.18447928e-02],
#        [ 6.24614970e-01, -1.01534404e-01, -7.06411424e-02],
#        [-4.52613000e-01, -1.29449457e-01,  1.17526538e-01],
#        [ 1.34074991e-01, -1.74231096e-01, -3.13845420e-02],
#        [ 6.07626792e-01, -1.55167134e-01, -3.85773015e-04],
#        [-1.43372930e+00,  5.46795630e-01,  4.92821989e-01],
#        [ 1.59141266e-01, -9.58410725e-02, -1.40036101e-01],
#        [-3.98307373e-01, -8.25318400e-02,  1.09854190e-02],
#        [ 2.31355060e-02, -1.63858407e-01, -3.14091893e-02],
#        [-1.00848903e-02, -1.66371863e-01, -2.10557981e-02],
#        [-4.25973509e-01,  5.65472841e-02, -1.51250847e-01],
#        [ 1.47044859e+00,  8.56249314e-01, -3.47774373e-01],
#        [-6.01546988e-02, -1.10809596e-01, -8.73925337e-02],
#        [ 1.21964813e-01, -1.97791094e-01,  5.04570926e-03],
#        [ 6.39824008e-01, -5.36615589e-02, -1.27756106e-01],
#        [-5.20805843e-01,  5.52133497e-01, -5.11003987e-01],
#        [-9.43843224e-01,  1.21303456e-01,  2.09910586e-01],
#        [-1.28440453e-01, -7.66562932e-02, -1.13554121e-01],
#        [-1.04630938e-01, -1.68827610e-01,  7.42445913e-03],
#        [-9.11728517e-01,  8.99616858e-02,  2.16337122e-01],
#        [-1.07709909e+00,  6.45783403e-02,  5.51052152e-01],
#        [ 7.59858431e-02,  3.82808602e-02, -2.86836193e-01],
#        [ 4.53304343e-01,  1.80663186e-02, -2.56457593e-01]])

# %%
df_pca = pd.DataFrame(df_pca, columns = ['Component 1', 'Component 2', 'Component 3'], index = df.index)
df_pca
# Out:
#          Component 1  Component 2  Component 3
# Country
# ABW        -1.179091     0.415042     0.154934
# AGO         1.066612     0.046432    -0.027981
# ALB        -0.192395    -0.160456     0.025658
# ARM        -0.132441    -0.176545     0.028269
# ATG        -1.132439     0.227025     0.333752
# ...              ...          ...          ...
# VUT        -0.104631    -0.168828     0.007424
# WSM        -0.911729     0.089962     0.216337
# YEM        -1.077099     0.064578     0.551052
# ZAF         0.075986     0.038281    -0.286836
# ZMB         0.453304     0.018066    -0.256458
#
# [163 rows x 3 columns]

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')


ax.scatter(df_pca.iloc[:, 0], df_pca.iloc[:, 1], df_pca.iloc[:, 2], 
           c=df_['Cluster'], cmap='viridis', alpha=0.7, edgecolors='k')


ax.set_title("3D Clustered PCA Plot")
ax.set_xlabel("Component 1")
ax.set_ylabel("Component 2")
ax.set_zlabel("Component 3")

cbar = plt.colorbar(ax.scatter(df_pca.iloc[:, 0], df_pca.iloc[:, 1], df_pca.iloc[:, 2], 
                               c=df_['Cluster'], cmap='viridis'))
cbar.set_label("Cluster Label")
plt.savefig("3D_PCA_Cluster.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Dimentionality reduction of UMAP

# %%
umap = UMAP(n_components = 3, random_state = 42)
df_umap = umap.fit_transform(df)
df_umap
# Out:
# array([[16.259703  ,  2.890769  ,  2.8680427 ],
#        [-4.3601923 ,  4.968551  ,  2.895726  ],
#        [ 7.9039893 , -1.2721345 ,  1.3024812 ],
#        [ 7.346052  , -2.2517805 ,  2.4244354 ],
#        [ 1.4928123 ,  1.764759  ,  5.103479  ],
#        [ 6.835671  ,  0.9567541 ,  2.4164262 ],
#        [15.909532  ,  3.3433523 ,  3.3964894 ],
#        [ 7.174855  , -1.0703696 ,  2.1627555 ],
#        [ 7.171808  , -2.3319206 ,  2.2759058 ],
#        [15.855188  ,  3.487193  ,  3.218035  ],
#        [16.342476  ,  3.2202692 ,  3.1172774 ],
#        [ 5.362275  ,  0.5004394 ,  3.7202282 ],
#        [ 4.0694976 ,  0.91011363,  4.396464  ]], dtype=float32)

# %%
df_umap = pd.DataFrame(df_umap, columns = ['Component 1', 'Component 2', 'Component 3'], index = df.index)

# %%
df_umap
# Out:
#          Component 1  Component 2  Component 3
# Country
# ABW        16.259703     2.890769     2.868043
# AGO        -4.360192     4.968551     2.895726
# ALB         7.903989    -1.272135     1.302481
# ARM         7.346052    -2.251781     2.424435
# ATG        16.356947     3.117596     2.936482
# ...              ...          ...          ...
# VUT         7.171808    -2.331921     2.275906
# WSM        15.855188     3.487193     3.218035
# YEM        16.342476     3.220269     3.117277
# ZAF         5.362275     0.500439     3.720228
# ZMB         4.069498     0.910114     4.396464
#
# [163 rows x 3 columns]

# %%
print(df_.columns)
# Out:
# Index(['Population_Coeff', 'Inflation_Coeff', 'Import_Coeff', 'Export_Coeff',
#        'Cluster'],
#       dtype='object')

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111, projection = '3d')

ax.scatter(df_umap.iloc[:,0], df_umap.iloc[:,1], df_umap.iloc[:,2], c = df_['Cluster'], cmap = 'viridis', alpha = 0.7, edgecolors = 'k')

cbar = plt.colorbar(ax.scatter(df_umap.iloc[:,0], df_umap.iloc[:,1], df_umap.iloc[:,2], c = df_['Cluster'], cmap = 'viridis', alpha = 0.7, edgecolors = 'k'))
cbar.set_label('Cluster Label')


ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
ax.set_zlabel('Component 3')
ax.set_title('3D Clustered UMAP Plot')
plt.savefig("3D_UMAP_Cluster.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Dimentionality reduction of Isomap

# %%
isomap = Isomap(n_components=3) 
df_isomap = isomap.fit_transform(df)
df_isomap
# Out:
# array([[-1.41591318e+00, -2.70483132e-01,  1.98889537e-01],
#        [ 1.18542590e+00, -5.61929232e-02,  8.41449890e-02],
#        [-1.95649943e-01, -1.00582774e-01, -5.64579051e-02],
#        [-1.32292079e-01, -1.01163446e-01, -5.07145862e-02],
#        [-1.30681648e+00, -3.46593834e-01,  1.48054292e-01],
#        [ 1.04722052e-01, -4.44955942e-02, -2.74612887e-02],
#        [-7.43928775e-02, -1.11044970e-01, -5.03149010e-02],
#        [ 2.14111735e+00, -2.25341163e-01,  9.34526763e-02],
#        [-3.54437491e-01, -3.65109120e-02, -5.44961252e-02],
#        [-8.11658226e-02, -1.07487796e-01, -5.02413846e-02],
#        [-3.87371499e-01,  5.38474511e-02, -1.44654419e-01],
#        [ 4.61009607e-01, -9.62717134e-03,  3.84295830e-02],
#        [ 1.72866764e-01,  1.10913014e-01, -7.94761205e-03],
#        [-5.80828976e-01, -1.51415156e-01,  9.84051075e-04],
#        [ 1.03513965e+00, -3.17338814e-02,  1.01520605e-01],
#        [ 8.04706617e-03,  3.21009970e-02, -3.37624500e-02],
#        [ 1.80679525e-01,  1.99245570e-01, -4.88488964e-02],
#        [-4.04125601e-01, -8.40971223e-03, -1.23084151e-01],
#        [ 5.18595061e-02, -5.09365071e-02, -1.08881339e-02],
#        [ 2.65649008e-02, -8.22332971e-02, -5.48180348e-02],
#        [-4.82634276e-01,  2.26961393e-01, -1.29542424e-01],
#        [ 2.08925409e+00, -1.68698049e-01, -1.87027998e-01],
#        [-4.55802954e-02,  4.07000974e-03, -3.35088580e-02],
#        [ 1.51598299e-01, -4.32889520e-02, -2.22387918e-02],
#        [ 7.15458789e-01,  3.84748179e-01,  5.77328270e-02],
#        [-7.83159642e-01,  7.41107917e-01,  1.62364305e-01],
#        [-1.06599435e+00, -2.44829903e-01,  1.42005127e-01],
#        [-1.10197210e-01,  5.82305901e-02, -9.01408728e-02],
#        [-1.07191492e-01, -9.12069535e-02, -8.19305342e-02],
#        [-1.02500764e+00, -2.60639438e-01,  1.02858504e-01],
#        [-1.38340114e+00, -4.19651712e-01, -1.41605783e-02],
#        [ 5.44909806e-02,  3.88279391e-01, -8.68377496e-02],
#        [ 4.57358019e-01,  3.87731719e-01, -3.93010144e-03]])

# %%
df_isomap = pd.DataFrame(df_isomap, columns = ['Component 1', 'Component 2', 'Component 3'], index = df.index)

# %%
df_isomap
# Out:
#          Component 1  Component 2  Component 3
# Country
# ABW        -1.415913    -0.270483     0.198890
# AGO         1.185426    -0.056193     0.084145
# ALB        -0.195650    -0.100583    -0.056458
# ARM        -0.132292    -0.101163    -0.050715
# ATG        -1.306816    -0.346594     0.148054
# ...              ...          ...          ...
# VUT        -0.107191    -0.091207    -0.081931
# WSM        -1.025008    -0.260639     0.102859
# YEM        -1.383401    -0.419652    -0.014161
# ZAF         0.054491     0.388279    -0.086838
# ZMB         0.457358     0.387732    -0.003930
#
# [163 rows x 3 columns]

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111, projection = '3d')

ax.scatter(df_isomap.iloc[:,2], df_isomap.iloc[:,1], df_isomap.iloc[:,0], c = df_['Cluster'], cmap = 'viridis', alpha = 0.7, edgecolors = 'k')

cbar = plt.colorbar(ax.scatter(df_isomap.iloc[:,0], df_isomap.iloc[:,1], df_isomap.iloc[:,2], c = df_['Cluster'], cmap = 'viridis', alpha = 0.7, edgecolors = 'k'))
cbar.set_label('Cluster Label')


ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
ax.set_zlabel('Component 3')
ax.set_title('3D Clustered Isomap Plot')
plt.savefig("3D_Isomap_Cluster.png", dpi=300, bbox_inches='tight')
plt.show()
