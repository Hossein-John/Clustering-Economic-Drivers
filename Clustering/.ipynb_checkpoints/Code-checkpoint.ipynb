# %%
from sklearn.decomposition import *
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import *
from umap import UMAP
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../Modeling/ridge_regression_coefficients_all_countries.csv', index_col = 0)

# %%
df.head()
# Out:
#          Best Alpha  Population_Coeff  Inflation_Coeff  Import_Coeff  \
# Country
# BDI            0.01          0.001293        -0.000388      0.000449
# BFA            0.01          0.019002        -0.002105      0.001540
# BGD            0.01          0.075913        -0.030418      0.033052
# BHR            0.01          0.006992        -0.020819      0.006354
# BHS            0.01          0.000291        -0.003714      0.001493
#
#          Export_Coeff     Score  Export_GDP_Correlation
# Country
# BDI     -2.183857e-07  0.862419                0.664439
# BFA      1.803168e-03  0.974553                0.951462
# BGD      1.773468e-02  0.983529                0.982825
# BHR      7.328568e-03  0.907860                0.926710
# BHS     -1.048423e-03  0.758223               -0.676031

# %%
df.drop(columns = ['Best Alpha', 'Score', 'Export_GDP_Correlation'], inplace = True)

# %%
df
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff
# Country
# BDI              0.001293        -0.000388      0.000449 -2.183857e-07
# BFA              0.019002        -0.002105      0.001540  1.803168e-03
# BGD              0.075913        -0.030418      0.033052  1.773468e-02
# BHR              0.006992        -0.020819      0.006354  7.328568e-03
# BHS              0.000291        -0.003714      0.001493 -1.048423e-03
# ...                   ...              ...           ...           ...
# VCT              0.000001        -0.000465      0.000188 -2.984769e-05
# VUT              0.000023        -0.000517      0.000162  7.897728e-06
# WSM              0.000003        -0.000153      0.000174  1.758584e-05
# ZAF              0.273448        -0.031052      0.037791  1.100602e-02
# ZMB              0.040171        -0.001174      0.002126  3.706496e-03
#
# [92 rows x 4 columns]

# %% [markdown]
# # remove outliers

# %%
'''
Q1 = df.quantile(0.1)
Q3 = df.quantile(0.9)
IQR = Q3 - Q1

outliers = ((df[df.columns] > Q3 + 1.5 * IQR) | (df[df.columns] < Q1 - 1.5 * IQR)).any(axis = 1)
print(outliers.sum())
print(df[outliers])
df = df[~outliers]
'''
# Out:
# '\nQ1 = df.quantile(0.1)\nQ3 = df.quantile(0.9)\nIQR = Q3 - Q1\n\noutliers = ((df[df.columns] > Q3 + 1.5 * IQR) | (df[df.columns] < Q1 - 1.5 * IQR)).any(axis = 1)\nprint(outliers.sum())\nprint(df[outliers])\ndf = df[~outliers]\n'

# %% [markdown]
# # KMeans clustering

# %%
from sklearn.cluster import KMeans
inertia_values = []

cluster_range = range(1, 11)
for k in cluster_range:
    model = KMeans(n_clusters=k, n_init=10, random_state=42)
    model.fit(df)
    inertia_values.append(model.inertia_)


plt.figure(figsize=(10, 6))
plt.plot(cluster_range, inertia_values, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow method for optimal')
plt.xticks(cluster_range)
plt.show()

# %%
n_clusters = 3
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df['Cluster'] = kmeans.fit_predict(df)

# %%
from sklearn.metrics import silhouette_score

sil_score = silhouette_score(df.drop(columns=['Cluster']), df['Cluster'])
print("Silhouette Score:", (sil_score + 1) / 2)
# Out:
# Silhouette Score: 0.9744737846484209

# %%
df.Cluster.value_counts()
# Out:
# Cluster
# 0    90
# 2     1
# 1     1
# Name: count, dtype: int64

# %% [markdown]
# # Decomposition without scaled

# %%
def visualize_dim_red(name, alg, data, clusters):
    al = alg(n_components=2)
    tr = al.fit_transform(data)

    plt.scatter(tr[:, 0], tr[:, 1], c=clusters, cmap='viridis', alpha=0.7, edgecolors='k')

    plt.title(name)
    plt.xlabel("Component 1")
    plt.ylabel("Component 2")
    plt.colorbar(label="Cluster Label")
    plt.show()

algs = {'PCA': PCA, 'tSNE': TSNE, 'UMAP': UMAP, 'ICA': FastICA, 'Isomap': Isomap}

 
clusters = df['Cluster']


df_features = df.drop(columns=['Cluster'])


for name, alg in algs.items():
    visualize_dim_red(name, alg, df_features, clusters)

# %%
df = df.rename(columns={'Cluster': 'Cluster_KMeans_Not_Scaled'})

# %%
df
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff  \
# Country
# BDI              0.001293        -0.000388      0.000449 -2.183857e-07
# BFA              0.019002        -0.002105      0.001540  1.803168e-03
# BGD              0.075913        -0.030418      0.033052  1.773468e-02
# BHR              0.006992        -0.020819      0.006354  7.328568e-03
# BHS              0.000291        -0.003714      0.001493 -1.048423e-03
# ...                   ...              ...           ...           ...
# VCT              0.000001        -0.000465      0.000188 -2.984769e-05
# VUT              0.000023        -0.000517      0.000162  7.897728e-06
# WSM              0.000003        -0.000153      0.000174  1.758584e-05
# ZAF              0.273448        -0.031052      0.037791  1.100602e-02
# ZMB              0.040171        -0.001174      0.002126  3.706496e-03
#
#          Cluster_KMeans_Not_Scaled
# Country
# BDI                              0
# ...

# %% [markdown]
# # Scaled data

# %%
from sklearn.preprocessing import StandardScaler
columns = df.columns
df_scaled = df.copy()
scaler = StandardScaler()
df_scaled[columns] = scaler.fit_transform(df[columns])

# %%
df_scaled
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff  \
# Country
# BDI             -0.222438         0.242120     -0.064915     -0.120418
# BFA             -0.204387         0.228542     -0.059982     -0.118933
# BGD             -0.146376         0.004718      0.082526     -0.105812
# BHR             -0.216630         0.080601     -0.038212     -0.114382
# BHS             -0.223460         0.215825     -0.060194     -0.121281
# ...                   ...              ...           ...           ...
# VCT             -0.223755         0.241507     -0.066095     -0.120442
# VUT             -0.223734         0.241096     -0.066214     -0.120411
# WSM             -0.223753         0.243977     -0.066158     -0.120403
# ZAF              0.054977        -0.000293      0.103957     -0.111353
# ZMB             -0.182809         0.235904     -0.057332     -0.117365
#
#          Cluster_KMeans_Not_Scaled
# Country
# BDI                      -0.141264
# ...

# %% [markdown]
# # Kmeans clustering

# %%
inertia_values = []

cluster_range = range(1, 11)
for k in cluster_range:
    model = KMeans(n_clusters=k, n_init=10, random_state=42)
    model.fit(df_scaled)
    inertia_values.append(model.inertia_)


plt.figure(figsize=(10, 6))
plt.plot(cluster_range, inertia_values, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow method for optimal')
plt.xticks(cluster_range)
plt.show()

# %%
n_clusters = 5
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df_scaled['Cluster'] = kmeans.fit_predict(df_scaled)

# %%
from sklearn.metrics import silhouette_score

sil_score = silhouette_score(df_scaled.drop(columns=['Cluster']), df_scaled['Cluster'])
print("Silhouette Score:", (sil_score + 1) / 2)
# Out:
# Silhouette Score: 0.9360533095108676

# %%
df_scaled.Cluster.value_counts()
# Out:
# Cluster
# 0    88
# 2     1
# 3     1
# 4     1
# 1     1
# Name: count, dtype: int64

# %% [markdown]
# # Decomposition with Scale

# %%
def visualize_dim_red(name, alg, data, clusters):
    al = alg(n_components=2)
    tr = al.fit_transform(data)
    plt.scatter(tr[:, 0], tr[:, 1], c=clusters, cmap='viridis', alpha=0.7, edgecolors='k')
    plt.title(name)
    plt.xlabel("Component 1")
    plt.ylabel("Component 2")
    plt.colorbar(label="Cluster Label")
    plt.show()

algs = {'PCA': PCA, 'tSNE': TSNE, 'UMAP':UMAP, 'ICA': FastICA, 'Isomap': Isomap}

clusters = df_scaled['Cluster']
df_features = df_scaled.drop(columns=['Cluster'])

for name, alg in algs.items():
    visualize_dim_red(name, alg, df_features, clusters)

# %%
df['Cluster_KMeans_with_Scaled'] = df_scaled['Cluster']

# %%
df
# Out:
#          Population_Coeff  Inflation_Coeff  Import_Coeff  Export_Coeff  \
# Country
# BDI              0.001293        -0.000388      0.000449 -2.183857e-07
# BFA              0.019002        -0.002105      0.001540  1.803168e-03
# BGD              0.075913        -0.030418      0.033052  1.773468e-02
# BHR              0.006992        -0.020819      0.006354  7.328568e-03
# BHS              0.000291        -0.003714      0.001493 -1.048423e-03
# ...                   ...              ...           ...           ...
# VCT              0.000001        -0.000465      0.000188 -2.984769e-05
# VUT              0.000023        -0.000517      0.000162  7.897728e-06
# WSM              0.000003        -0.000153      0.000174  1.758584e-05
# ZAF              0.273448        -0.031052      0.037791  1.100602e-02
# ZMB              0.040171        -0.001174      0.002126  3.706496e-03
#
#          Cluster_KMeans_Not_Scaled  Cluster_KMeans_with_Scaled
# Country
# ...

# %%
df.to_csv('../Modeling/clustered_data.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df.to_csv('../Modeling/clustered_data.csv')
#
# File c:\users\hossein ahmadi\desktop\projects\qenv\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
